# %%
import pandas as pd

# %%
df = pd.read_csv("crime_data.csv")
print(df.head())
# Out:
#            dateEncoded    pro      ppo               stn  pcp  \
# 0  2025-01-03 01:19:10  NCRPO  SPD HQS  PS 01 Pasay City  NaN
# 1  2025-01-02 04:02:08  NCRPO  SPD HQS  PS 01 Pasay City  NaN
# 2  2025-01-07 21:58:27  NCRPO  SPD HQS  PS 01 Pasay City  NaN
# 3  2025-01-05 23:08:49  NCRPO  SPD HQS  PS 01 Pasay City  NaN
# 4  2025-01-05 01:49:01  NCRPO  SPD HQS  PS 01 Pasay City  NaN
#
#                     region  province   municipal      barangay  \
# 0  NATIONAL CAPITAL REGION  SOUTHERN  PASAY CITY   BARANGAY 76
# 1  NATIONAL CAPITAL REGION  SOUTHERN  PASAY CITY  BARANGAY 176
# 2  NATIONAL CAPITAL REGION  SOUTHERN  PASAY CITY  BARANGAY 183
# 3  NATIONAL CAPITAL REGION  SOUTHERN  PASAY CITY    BARANGAY 4
# 4  NATIONAL CAPITAL REGION  SOUTHERN  PASAY CITY   BARANGAY 47
#
#                     street  ... vehicleChassisNo vehicleKind vehicleMake  \
# 0               ROXAS BLVD  ...              NaN         NaN         NaN
# 1                E. FLORES  ...              NaN         NaN         NaN
# 2                     14TH  ...              NaN         NaN         NaN
# 3  \"RODRIQUES, CUYRGING\"  ...              NaN         NaN         NaN
# 4                 SANDEJAS  ...              NaN         NaN         NaN
#
#   vehicleModel vehicleStatus vehicleRegistrationNo vehicleRegistrationStatus  \
# 0          NaN           NaN                   NaN                       NaN
# 1          NaN           NaN                   NaN                       NaN
# 2          NaN           NaN                   NaN                       NaN
# 3          NaN           NaN                   NaN                       NaN
# 4          NaN           NaN                   NaN                       NaN
#
#   vehicleColorum gambling_kind amount
# 0            NaN           NaN    NaN
# 1            NaN           NaN    NaN
# 2            NaN           NaN    NaN
# 3            NaN           NaN    NaN
# 4            NaN           NaN    NaN
#
# [5 rows x 79 columns]

# %%
df = df.dropna(axis=1, how="all")

print(df.columns)
# Out:
# Index(['dateEncoded', 'pro', 'ppo', 'stn', 'region', 'province', 'municipal',
#        'barangay', 'street', 'typeofPlace', 'dateReported', 'timeReported',
#        'dateCommitted', 'MONTH', 'timeCommitted', 'incidentType', 'iscime',
#        'mode_reporting', 'stageoffelony', 'offense', 'offenseType', 'section',
#        'modus', 'threatGrp', 'mrs', 'suspectisEGO', 'suspectEGOPosition',
#        'suspectEGOClass', 'victimisEGO', 'victimEGOPosition', 'victimEGOClass',
#        'suspectMotive', 'victimKilled', 'victimInjured', 'victimUnharmed',
#        'suspectKilled', 'suspectAtLarge', 'suspectArrested', 'casestatus',
#        'caseSolveType', 'caseStatusinProsec', 'groundDismissedProsec',
#        'fillingType', 'dateFiledtoProsec', 'caseCourtStatus',
#        'dateFiledInCourt', 'ccNo', 'judge', 'court', 'lat', 'lng',
#        'victimCount', 'suspectCount', 'robStablishmentType',
#        'robStablishmentName', 'faserialno', 'facaliber', 'fakind', 'famake',
#        'fastatus', 'drugInvolved', 'vehiclePlateNo', 'vehicleMCPlateNo',
#        'vehicleKind', 'vehicleMake', 'vehicleModel'],
#       dtype='object')

# %%
df = df[[
    "dateCommitted", #
    "timeCommitted", #
    "barangay", #
    "municipal", #
    "lat", #
    "lng", #
    "offense", #
    "offenseType", #
    "incidentType", #
    "typeofPlace", #
    "victimCount", #
    "suspectCount", #
    "victimKilled", #
    "victimInjured", #
]]

print(df.head())
# Out:
#   dateCommitted timeCommitted      barangay   municipal        lat  \
# 0    2025-01-01      23:22:00   BARANGAY 76  PASAY CITY  14.554174
# 1    2025-01-01      13:15:00  BARANGAY 176  PASAY CITY  14.532466
# 2    2025-01-02      01:00:00  BARANGAY 183  PASAY CITY  14.529854
# 3    2025-01-04      22:40:00    BARANGAY 4  PASAY CITY  14.556959
# 4    2025-01-04      10:15:00   BARANGAY 47  PASAY CITY  14.550999
#
#           lng             offense              offenseType  \
# 0  120.989258            ROBBERY   Crimes Against Property
# 1  121.010574             MURDER    Crimes Against Persons
# 2  121.015091               RAPE    Crimes Against Persons
# 3  120.999199  PHYSICAL INJURIES    Crimes Against Persons
# 4  120.990311             THEFT    Crimes Against Property
#
#              incidentType                        typeofPlace  victimCount  \
# 0      (Incident) Robbery                   Along the street            1
# 1     (Incident) Shooting                   Along the street            1
# 2         (Incident) Rape          Residential (house/condo)            1
# 3  (Incident) Child Abuse                   Along the street            1
# 4        (Incident) Theft  Commercial/Business Establishment            1
#
#    suspectCount victimKilled victimInjured
# 0             1           No            No
# 1             1           No            No
# 2             1           No            No
# 3             5           No           Yes
# 4             1           No            No

# %%
df = df.copy()
df["dateCommitted"] = pd.to_datetime(df["dateCommitted"])

# %% [markdown]
# this converts date committed into individual months, time, and day of the week

# %%
df["month"] = df["dateCommitted"].dt.month
df["day_of_week"] = df["dateCommitted"].dt.dayofweek
df["hour"] = df["dateCommitted"].dt.hour

# %%
df = pd.get_dummies(df, columns=[
    "offenseType",
    "incidentType",
    "typeofPlace"
])

# %%
crime_counts = df.groupby("barangay").size()

df["areaCrimeCount"] = df["barangay"].map(crime_counts)

# %%
df["barangay_encoded"] = df["barangay"].astype("category").cat.codes
df["municipal_encoded"] = df["municipal"].astype("category").cat.codes

# %%
df["lat_encoded"] = df["lat"].astype("float64")
df["lng_encoded"] = df["lng"].astype("float64")

# %%
df["victimCount_encoded"] = pd.to_numeric(df["victimCount"],errors="coerce").fillna(0)
df["suspectCount_encoded"] = pd.to_numeric(df["suspectCount"],errors="coerce").fillna(0)
df["victimKilled"] = pd.to_numeric(df["victimKilled"], errors='coerce').fillna(0)
df["victimKilled_binary"] = (df["victimKilled"] > 0).astype(int)
df["victimInjured_encoded"] = pd.to_numeric(df["victimInjured"], errors="coerce").fillna(0)

# %%
df.to_csv("processed_crime_data.csv", index=False)
print("Dataframe saved to: processed_crime_data.csv")
# Out:
# Dataframe saved to: processed_crime_data.csv

# %% [markdown]
# `
